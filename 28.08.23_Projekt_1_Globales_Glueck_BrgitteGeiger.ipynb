# %%
# https://www.urlaubsguru.de/reisemagazin/world-happiness-report/


import pandas as pd
import numpy as np
import matplotlib


lucky_country = pd.read_csv("Glueck_2018-2019.csv")
lucky_country
# Out:
#      Overall rank Country or region  Year  Score  GDP per capita  \
# 0             154       Afghanistan  2019  3.203           0.350
# 1             145       Afghanistan  2018  3.632           0.332
# 2             107           Albania  2019  4.719           0.947
# 3             112           Albania  2018  4.586           0.916
# 4              88           Algeria  2019  5.211           1.002
# ..            ...               ...   ...    ...             ...
# 307           152             Yemen  2018  3.355           0.442
# 308           138            Zambia  2019  4.107           0.578
# 309           125            Zambia  2018  4.377           0.562
# 310           146          Zimbabwe  2019  3.663           0.366
# 311           144          Zimbabwe  2018  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.517                    0.361                         0.000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Glueck_2018-2019.csv")

df.plot()

plt.show()

# %%
#lucky_country = pd.read_csv("Glueck_2018-2019.csv")
# laender_score = lucky_country['Country or region'].unique()
#laender_score = lucky_country[['Country or region', 'Score']].sort_values(by='Score')
#laender_score

# %%
#import pandas as pd
#import numpy as np

#lucky_country = pd.read_csv("Glueck_2018-2019.csv")
#laender_score = lucky_country[['Country or region', 'Score']].sort_values()

#laender_score

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

lucky_country2018 = pd.read_csv("Glueck_2018.csv")
lucky_country2018
#laender_score = lucky_country2018[['Country or region', 'Score', ]].sort_values(by='Score', ascending=False))
#laender_score
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
lucky_country2019 = pd.read_csv("Glueck_2019.csv")
lucky_country2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
happy_score2019 = lucky_country2019.sort_values(by='Score', ascending=False)
happy_score2019 = happy_score2019.head(10)
happy_score2019
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sehen Sie sich die Verteilung der Glückswerte an, indem Sie Mittelwerte (rot) und Medianwerte (schwarz) einzeichnen

plt.figure(figsize=(10,8))
plt.title("Verteilung der Glückspunktzahl(Ranking) der Top 10 Länder 2019", fontsize = 14)
plt.xlabel('Glückspunktzahl(Ranking)')
plt.ylabel('Anzahl der Länder')
plt.hist(x = lucky_country2019['Score'], bins = np.arange(0,10, 0.5), edgecolor = 'white')
plt.axvline(x=lucky_country2019['Score'].mean(), color = 'red')
plt.axvline(x=lucky_country2019['Score'].median(), color = 'black')

plt.show()

# %%
# https://www.kaggle.com/datasets/ajaypalsinghlo/world-happiness-report-2023?resource=download

lucky_country2023 = pd.read_csv("WHR2023.csv")
lucky_country2023

#laender_score2023 = lucky_country2023[['Country name', 'Ladder score']].sort_values(by='Ladder score', ascending=False)
#laender_score2023
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 0             Finland         7.804                           0.036
# 1             Denmark         7.586                           0.041
# 2             Iceland         7.530                           0.049
# 3              Israel         7.473                           0.032
# 4         Netherlands         7.403                           0.029
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)         3.207                           0.095
# 133          Zimbabwe         3.204                           0.061
# 134      Sierra Leone         3.138                           0.082
# 135           Lebanon         2.392                           0.044
# 136       Afghanistan         1.859                           0.033
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0           7.875         7.733                 10.792           0.969
# ...

# %%
# Daten aus der CSV-Datei laden
lucky_country2023 = pd.read_csv("WHR2023.csv")

# Länderranking erstellen
ranking = lucky_country2023.sort_values(by='Ladder score', ascending=False)

ranking = ranking.head(10)

# Donut-Plot erstellen
plt.pie(ranking["Ladder score"], labels=ranking["Country name"], autopct="%1.1f%%", startangle=90)
plt.axis("equal") # Kreisförmige Darstellung sicherstellen
plt.title("Die Top 10 der glücklichsten Länder 2023")
# plt.legend()

# Diagramm anzeigen
plt.show()

# %%
# Erstellen von Top-10- und Bottom-10-Datenrahmen und Verknüpfen dieser Datenrahmen
top10 = lucky_country2023.set_index('Country name')['Ladder score'].nlargest(10).to_frame()
bottom10 = lucky_country2023.set_index('Country name')['Ladder score'].nsmallest(10).to_frame()
dfconcat = pd.concat([top10, bottom10], axis=0)
dfconcat = dfconcat.sort_values(by="Ladder score")

fig = plt.figure(figsize=(10,8))
cmap = plt.cm.RdYlGn
norm = plt.Normalize(vmin=dfconcat['Ladder score'].min(), vmax=dfconcat['Ladder score'].max())
colors = [cmap(norm(value)) for value in dfconcat['Ladder score']]

g = plt.barh(y=dfconcat.index, width=dfconcat["Ladder score"], color=colors)
plt.ylabel("Länder")
plt.xlabel("Glückpunktzahl")
plt.title("Die 10 glücklichsten und am wenigsten glücklichsten Länder 2023", fontsize = 20)

plt.show()

# %%
# Sehen Sie sich die Verteilung der Glückswerte an, indem Sie Mittelwerte (rot) und Medianwerte (schwarz) einzeichnen

plt.figure(figsize=(10,8))
plt.title("Verteilung der Glückpunktzahl(Ranking) der Top 10 Länder 2023", fontsize = 20)
plt.xlabel('Glückspunktzahl(Ranking)')
plt.ylabel('Anzahl der Länder')
plt.legend('Top 10 Länder')
plt.hist(top10, bins = np.arange(0.2,10, 0.5), edgecolor = 'white')

plt.axvline(x = top10['Ladder score'].mean(), color = 'red')
plt.axvline(x = top10['Ladder score'].median(), color = 'black')

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Lassen Sie uns Schätzungen der Kerndichte für die 6 Faktoren erstellen

fig = plt. figure()
fig, axes = plt.subplots(2, 3, figsize= (10, 6))
plt.tight_layout(pad= 3)

plta = sns.kdeplot( data=lucky_country2023, x='Logged GDP per capita',color='#37F090',fill=True, ax=axes[0,0])
pltb = sns.kdeplot( data=lucky_country2023, x='Healthy life expectancy',color='#00D0A3',fill=True, ax=axes[0,1])
pltc = sns.kdeplot( data=lucky_country2023, x='Social support',color='#00ADA7',fill=True, ax=axes[0,2])
pltd = sns.kdeplot( data=lucky_country2023, x='Freedom to make life choices',color='#008A9A',fill=True, ax=axes[1,0])
plte = sns.kdeplot( data=lucky_country2023, x='Generosity',color='#08687E',fill=True, ax=axes[1,1])
pltf = sns.kdeplot( data=lucky_country2023, x='Perceptions of corruption',color='#2F4858',fill=True, ax=axes[1,2])

plta.axvline(x = lucky_country2023['Logged GDP per capita'].mean(), color = 'red')
plta.axvline(x = lucky_country2023['Logged GDP per capita'].median(), color = 'black')
pltb.axvline(x = lucky_country2023['Healthy life expectancy'].mean(), color = 'red')
pltb.axvline(x = lucky_country2023['Healthy life expectancy'].median(), color = 'black')
pltc.axvline(x = lucky_country2023['Social support'].mean(), color = 'red')
pltc.axvline(x = lucky_country2023['Social support'].median(), color = 'black')
pltd.axvline(x = lucky_country2023['Freedom to make life choices'].mean(), color = 'red')
pltd.axvline(x = lucky_country2023['Freedom to make life choices'].median(), color = 'black')
plte.axvline(x = lucky_country2023['Generosity'].mean(), color = 'red')
plte.axvline(x = lucky_country2023['Generosity'].median(), color = 'black')
pltf.axvline(x = lucky_country2023['Perceptions of corruption'].mean(), color = 'red')
pltf.axvline(x = lucky_country2023['Perceptions of corruption'].median(), color = 'black')
pltf.axvline(x = lucky_country2023['Perceptions of corruption'].median(), color = 'black')

plt.show()

# %%
# Lassen Sie uns den durchschnittlichen Glückswert für jede Region ermitteln

mean_happiness = lucky_country2023.groupby('Country name')[['Ladder score']].mean()
mean_happiness = mean_happiness.sort_values(by=['Ladder score'], ascending=False)
mean_happiness
# Out:
#                   Ladder score
# Country name
# Finland                  7.804
# Denmark                  7.586
# Iceland                  7.530
# Israel                   7.473
# Netherlands              7.403
# ...                        ...
# Congo (Kinshasa)         3.207
# Zimbabwe                 3.204
# Sierra Leone             3.138
# Lebanon                  2.392
# Afghanistan              1.859
#
# [137 rows x 1 columns]
